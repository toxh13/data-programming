# %%
import pandas as pd
drama=pd.read_csv('D:GC/top100_kdrama.csv')
drama
# Out:
#                              Name  Year of release  \
# 0                  Move to Heaven             2021
# 1               Hospital Playlist             2020
# 2                  Flower of Evil             2020
# 3             Hospital Playlist 2             2021
# 4                       My Mister             2018
# ..                            ...              ...
# 95                       Vagabond             2019
# 96                    Doctor John             2019
# 97       When the Camellia Blooms             2019
# 98  Because This Is My First Life             2017
# 99               Fight For My Way             2017
#
#                      Aired Date              Aired On  Number of Episode  \
# 0                  May 14, 2021                Friday                 10
# 1   Mar 12, 2020 - May 28, 2020              Thursday                 12
# 2   Jul 29, 2020 - Sep 23, 2020   Wednesday, Thursday                 16
# ...

# %%
drama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               100 non-null    object
#  1   Year of release    100 non-null    int64
#  2   Aired Date         100 non-null    object
#  3   Aired On           100 non-null    object
#  4   Number of Episode  100 non-null    int64
#  5   Network            100 non-null    object
#  6   Duration           100 non-null    object
#  7   Content Rating     100 non-null    object
#  8   Synopsis           100 non-null    object
#  9   Cast               100 non-null    object
#  10  Genre              100 non-null    object
#  11  Tags               100 non-null    object
#  12  Rank               100 non-null    object
#  13  Rating             100 non-null    float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 11.1+ KB

# %%
drama.describe()
# Out:
#        Year of release  Number of Episode      Rating
# count       100.000000         100.000000  100.000000
# mean       2017.970000          19.070000    8.723000
# std           2.869044          12.378096    0.174573
# min        2003.000000           6.000000    8.500000
# 25%        2017.000000          16.000000    8.600000
# 50%        2019.000000          16.000000    8.700000
# 75%        2020.000000          20.000000    8.800000
# max        2021.000000         100.000000    9.200000

# %%
d=drama.sort_values('Year of release')
d.head()
# Out:
#                    Name  Year of release                   Aired Date  \
# 64  Jewel in the Palace             2003  Sep 15, 2003 - Mar 23, 2004
# 62      The Bridal Mask             2012  May 30, 2012 - Sep  6, 2012
# 88           Reply 1997             2012  Jul 24, 2012 - Sep 18, 2012
# 80     The Master's Sun             2013  Aug  7, 2013 - Oct  3, 2013
# 74           Cruel City             2013  May 27, 2013 - Jul 30, 2013
#
#                 Aired On  Number of Episode Network      Duration  \
# 64       Monday, Tuesday                 54    MBC   1 hr. 5 min.
# 62   Wednesday, Thursday                 28   KBS2   1 hr. 5 min.
# 88               Tuesday                 16    tvN        60 min.
# 80   Wednesday, Thursday                 17    SBS   1 hr. 2 min.
# 74       Monday, Tuesday                 20   jTBC        60 min.
#
#               Content Rating  \
# 64  13+ - Teens 13 or older
# 62  15+ - Teens 15 or older
# 88  15+ - Teens 15 or older
# ...

# %%
d=drama[['Name','Year of release','Rating']]
d
# Out:
#                              Name  Year of release  Rating
# 0                  Move to Heaven             2021     9.2
# 1               Hospital Playlist             2020     9.1
# 2                  Flower of Evil             2020     9.1
# 3             Hospital Playlist 2             2021     9.1
# 4                       My Mister             2018     9.1
# ..                            ...              ...     ...
# 95                       Vagabond             2019     8.5
# 96                    Doctor John             2019     8.5
# 97       When the Camellia Blooms             2019     8.5
# 98  Because This Is My First Life             2017     8.5
# 99               Fight For My Way             2017     8.5
#
# [100 rows x 3 columns]

# %%
dr=d.sort_values('Rating')
dr.head(10)
# Out:
#                              Name  Year of release  Rating
# 99               Fight For My Way             2017     8.5
# 85                          Rebel             2017     8.5
# 86                   Nobody Knows             2020     8.5
# 87              I Hear Your Voice             2013     8.5
# 88                     Reply 1997             2012     8.5
# 89                         Kairos             2020     8.5
# 90      Dali and the Cocky Prince             2021     8.5
# 98  Because This Is My First Life             2017     8.5
# 92      Arthdal Chronicles Part 1             2019     8.5
# 93                Beautiful World             2019     8.5

# %%
count=drama['Number of Episode'].value_counts()
pd.DataFrame('network')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 count=drama['Number of Episode'].value_counts()
# ----> 2 pd.DataFrame('network')
#
# File C:\anaconda\Lib\site-packages\pandas\core\frame.py:781, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     778 # For data is scalar
#     779 else:
#     780     if index is None or columns is None:
# --> 781         raise ValueError("DataFrame constructor not properly called!")
#     783     index = ensure_index(index)
#     784     columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
dmax=drama['Rating']==drama['Rating'].max()
drama[dmax]
# Out:
#              Name  Year of release    Aired Date Aired On  Number of Episode  \
# 0  Move to Heaven             2021  May 14, 2021   Friday                 10
#
#     Network Duration                          Content Rating  \
# 0  Netflix   52 min.  18+ Restricted (violence & profanity)
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
#
#                                                 Cast                   Genre  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...  Life,  Drama,  Family
#
#                                                 Tags Rank  Rating
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...   #1     9.2

# %%
dmin=drama['Rating']==drama['Rating'].min()
drama[dmin]['Name']
# Out:
# 85                              Rebel
# 86                       Nobody Knows
# 87                  I Hear Your Voice
# 88                         Reply 1997
# 89                             Kairos
# 90          Dali and the Cocky Prince
# 91                       Yumi's Cells
# 92          Arthdal Chronicles Part 1
# 93                    Beautiful World
# 94    What's Wrong with Secretary Kim
# 95                           Vagabond
# 96                        Doctor John
# 97           When the Camellia Blooms
# 98      Because This Is My First Life
# 99                   Fight For My Way
# Name: Name, dtype: object

# %%
d=drama['Name'].str.contains('Love')
drama[d].head()
# Out:
#                       Name  Year of release                   Aired Date  \
# 52             Moon Lovers             2016  Aug 29, 2016 - Nov  1, 2016
# 60  It's Okay, That's Love             2014  Jul 23, 2014 - Sep 11, 2014
# 70   My Love from the Star             2013  Dec 18, 2013 - Feb 27, 2014
# 77     Just Between Lovers             2017  Dec 11, 2017 - Jan 30, 2018
#
#                 Aired On  Number of Episode Network       Duration  \
# 52       Monday, Tuesday                 20    SBS         60 min.
# 60   Wednesday, Thursday                 16    SBS         60 min.
# 70   Wednesday, Thursday                 21    SBS         58 min.
# 77       Monday, Tuesday                 16   jTBC   1 hr. 13 min.
#
#               Content Rating  \
# 52  15+ - Teens 15 or older
# 60  15+ - Teens 15 or older
# 70  15+ - Teens 15 or older
# 77  15+ - Teens 15 or older
#
#                                              Synopsis  \
# ...

# %%
d=(drama['Number of Episode']<=10)|(drama['Rating']>=9.0)
drama[d].head()
# Out:
#                   Name  Year of release                   Aired Date  \
# 0       Move to Heaven             2021                 May 14, 2021
# 1    Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2       Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3  Hospital Playlist 2             2021  Jun 17, 2021 - Sep 16, 2021
# 4            My Mister             2018  Mar 21, 2018 - May 17, 2018
#
#                Aired On  Number of Episode         Network       Duration  \
# 0                Friday                 10        Netflix         52 min.
# 1              Thursday                 12  Netflix,  tvN   1 hr. 30 min.
# 2   Wednesday, Thursday                 16            tvN   1 hr. 10 min.
# 3              Thursday                 12  Netflix,  tvN   1 hr. 40 min.
# 4   Wednesday, Thursday                 16            tvN   1 hr. 17 min.
#
#                            Content Rating  \
# 0  18+ Restricted (violence & profanity)
# ...

# %%
d=(drama['Number of Episode']==drama['Number of Episode'].min()) & (drama['Rating']>=8.5)
drama[d]
# Out:
#                          Name  Year of release                   Aired Date  \
# 16                    Kingdom             2020                 Mar 13, 2020
# 23                       D.P.             2021                 Aug 27, 2021
# 24                    Kingdom             2019                 Jan 25, 2019
# 45  Arthdal Chronicles Part 2             2019  Jun 22, 2019 - Jul  7, 2019
# 47  Arthdal Chronicles Part 3             2019  Sep  7, 2019 - Sep 22, 2019
# 92  Arthdal Chronicles Part 1             2019  Jun  1, 2019 - Jun 16, 2019
#
#              Aired On  Number of Episode         Network       Duration  \
# 16             Friday                  6        Netflix         45 min.
# 23             Friday                  6        Netflix         50 min.
# 24             Friday                  6        Netflix         51 min.
# 45   Saturday, Sunday                  6  Netflix,  tvN   1 hr. 21 min.
# 47   Saturday, Sunday                  6  Netflix,  tvN   1 hr. 20 min.
# ...

# %%
drama['CastCount']=drama['Cast'].str.count(',')+1
drama.head()
# Out:
#                   Name  Year of release                   Aired Date  \
# 0       Move to Heaven             2021                 May 14, 2021
# 1    Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2       Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3  Hospital Playlist 2             2021  Jun 17, 2021 - Sep 16, 2021
# 4            My Mister             2018  Mar 21, 2018 - May 17, 2018
#
#                Aired On  Number of Episode         Network       Duration  \
# 0                Friday                 10        Netflix         52 min.
# 1              Thursday                 12  Netflix,  tvN   1 hr. 30 min.
# 2   Wednesday, Thursday                 16            tvN   1 hr. 10 min.
# 3              Thursday                 12  Netflix,  tvN   1 hr. 40 min.
# 4   Wednesday, Thursday                 16            tvN   1 hr. 17 min.
#
#                            Content Rating  \
# 0  18+ Restricted (violence & profanity)
# ...

# %%
d=drama['Synopsis'].str.contains('Korea | US | U.S')
drm=drama[d]

# %%
d=drama.groupby(['Year of release','Network'])['Name'].count()
pd.DataFrame(d)
# Out:
#                                  Name
# Year of release Network
# 2003            MBC                 1
# 2012            KBS2                1
#                 tvN                 1
# 2013            MBC                 1
#                 SBS                 3
#                 jTBC                1
# 2014            KBS2                1
#                 OCN                 1
#                 SBS                 1
#                 tvN                 1
# 2015            MBC                 1
#                 SBS                 1
#                 tvN                 1
# 2016            KBS2                1
#                 MBC                 1
#                 SBS                 2
#                 jTBC                1
#                 tvN                 3
# 2017            KBS2                4
#                 MBC                 1
#                 Netflix,  tvN       2
#                 OCN                 2
#                 SBS                 2
# ...

# %%
d=drama.groupby(['Year of release','Network'])['Genre'].count()
pd.DataFrame(d)
# Out:
#                                  Genre
# Year of release Network
# 2003            MBC                  1
# 2012            KBS2                 1
#                 tvN                  1
# 2013            MBC                  1
#                 SBS                  3
#                 jTBC                 1
# 2014            KBS2                 1
#                 OCN                  1
#                 SBS                  1
#                 tvN                  1
# 2015            MBC                  1
#                 SBS                  1
#                 tvN                  1
# 2016            KBS2                 1
#                 MBC                  1
#                 SBS                  2
#                 jTBC                 1
#                 tvN                  3
# 2017            KBS2                 4
#                 MBC                  1
#                 Netflix,  tvN        2
#                 OCN                  2
# ...

# %%
drama['GenreCount']=drama['Genre'].str.contains(',')+1
drama.head()
# Out:
#                   Name  Year of release                   Aired Date  \
# 0       Move to Heaven             2021                 May 14, 2021
# 1    Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2       Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3  Hospital Playlist 2             2021  Jun 17, 2021 - Sep 16, 2021
# 4            My Mister             2018  Mar 21, 2018 - May 17, 2018
#
#                Aired On  Number of Episode         Network       Duration  \
# 0                Friday                 10        Netflix         52 min.
# 1              Thursday                 12  Netflix,  tvN   1 hr. 30 min.
# 2   Wednesday, Thursday                 16            tvN   1 hr. 10 min.
# 3              Thursday                 12  Netflix,  tvN   1 hr. 40 min.
# 4   Wednesday, Thursday                 16            tvN   1 hr. 17 min.
#
#                            Content Rating  \
# 0  18+ Restricted (violence & profanity)
# ...

# %%
from collections import Counter
drama['Cast'] = drama['Cast'].str.strip()
genre_list = list()
for genres in drama['Cast'].to_list():
    genres = genres.split(",")
    for gen in genres:
        genre_list.append(gen)       
genre_df = pd.DataFrame.from_dict(Counter(genre_list), orient = 'index').rename(columns = {0:'Count'})
genre_df.sort_values('Count',ascending = False, inplace = True)
genre_df.head()
# Out:
#                 Count
#  Lee Joon Hyuk      5
# Song Joong Ki       5
#  Kim Ji Won         5
#  Yoo Yeon Seok      4
#  Bae Doo Na         4

# %%
drm
# Out:
#                          Name  Year of release                   Aired Date  \
# 17               Mr. Sunshine           2018.0  Jul  7, 2018 - Sep 30, 2018
# 27            The Devil Judge           2021.0  Jul  3, 2021 - Aug 22, 2021
# 39         Chicago Typewriter           2017.0  Apr  7, 2017 - Jun  3, 2017
# 52                Moon Lovers           2016.0  Aug 29, 2016 - Nov  1, 2016
# 64        Jewel in the Palace           2003.0  Sep 15, 2003 - Mar 23, 2004
# Aired On                  NaN              NaN                          NaN
#
#                   Aired On  Number of Episode         Network       Duration  \
# 17        Saturday, Sunday               24.0  Netflix,  tvN   1 hr. 20 min.
# 27        Saturday, Sunday               16.0            tvN   1 hr. 10 min.
# 39        Friday, Saturday               16.0            tvN   1 hr. 10 min.
# 52         Monday, Tuesday               20.0            SBS         60 min.
# ...

# %%
from collections import Counter
drm['Aired On'] = drm['Aired On'].str.strip()
genre_list = list()
for genres in drm['Aired On'].to_list():
    genres = genres.split(",")
    for gen in genres:
        genre_list.append(gen)       
genre_df = pd.DataFrame.from_dict(Counter(genre_list), orient = 'index').rename(columns = {0:'Count'})
genre_df.sort_values('Count',ascending = False, inplace = True)
genre_df.head()
# Out:
# C:\TempFolder\ipykernel_14072\3273460760.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drm['Aired On'] = drm['Aired On'].str.strip()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 5
#       3 genre_list = list()
#       4 for genres in drm['Aired On'].to_list():
# ----> 5     genres = genres.split(",")
#       6     for gen in genres:
#       7         genre_list.append(gen)
#
# AttributeError: 'float' object has no attribute 'split'

# %%
plt.figure(figsize=(25,10))
plt.plot(genre_df,color='r',marker='o')
plt.bar(genre_df.index,genre_df.Count)
plt.title('장')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()
# Out:
# C:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47476 (\N{HANGUL SYLLABLE REU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
