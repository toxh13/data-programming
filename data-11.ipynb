# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
df = pd.read_csv('D:GC/abalone.csv')
df
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4176 rows x 9 columns]

# %%
df.columns = ['Sex','Length','Diam','Height','Whole','Shucked','Viscera','Shell','Rings']
df
# Out:
#      Sex  Length   Diam  Height   Whole  Shucked  Viscera   Shell  Rings
# 0      M   0.350  0.265   0.090  0.2255   0.0995   0.0485  0.0700      7
# 1      F   0.530  0.420   0.135  0.6770   0.2565   0.1415  0.2100      9
# 2      M   0.440  0.365   0.125  0.5160   0.2155   0.1140  0.1550     10
# 3      I   0.330  0.255   0.080  0.2050   0.0895   0.0395  0.0550      7
# 4      I   0.425  0.300   0.095  0.3515   0.1410   0.0775  0.1200      8
# ...   ..     ...    ...     ...     ...      ...      ...     ...    ...
# 4171   F   0.565  0.450   0.165  0.8870   0.3700   0.2390  0.2490     11
# 4172   M   0.590  0.440   0.135  0.9660   0.4390   0.2145  0.2605     10
# 4173   M   0.600  0.475   0.205  1.1760   0.5255   0.2875  0.3080      9
# 4174   F   0.625  0.485   0.150  1.0945   0.5310   0.2610  0.2960     10
# 4175   M   0.710  0.555   0.195  1.9485   0.9455   0.3765  0.4950     12
#
# [4176 rows x 9 columns]

# %%
label=LabelEncoder()
df['Sex']=label.fit_transform(df['Sex'])
df
# Out:
#       Sex  Length   Diam  Height   Whole  Shucked  Viscera   Shell  Rings
# 0       2   0.350  0.265   0.090  0.2255   0.0995   0.0485  0.0700      7
# 1       0   0.530  0.420   0.135  0.6770   0.2565   0.1415  0.2100      9
# 2       2   0.440  0.365   0.125  0.5160   0.2155   0.1140  0.1550     10
# 3       1   0.330  0.255   0.080  0.2050   0.0895   0.0395  0.0550      7
# 4       1   0.425  0.300   0.095  0.3515   0.1410   0.0775  0.1200      8
# ...   ...     ...    ...     ...     ...      ...      ...     ...    ...
# 4171    0   0.565  0.450   0.165  0.8870   0.3700   0.2390  0.2490     11
# 4172    2   0.590  0.440   0.135  0.9660   0.4390   0.2145  0.2605     10
# 4173    2   0.600  0.475   0.205  1.1760   0.5255   0.2875  0.3080      9
# 4174    0   0.625  0.485   0.150  1.0945   0.5310   0.2610  0.2960     10
# 4175    2   0.710  0.555   0.195  1.9485   0.9455   0.3765  0.4950     12
#
# [4176 rows x 9 columns]

# %%
y=df['Rings']
y
# Out:
# 0        7
# 1        9
# 2       10
# 3        7
# 4        8
#         ..
# 4171    11
# 4172    10
# 4173     9
# 4174    10
# 4175    12
# Name: Rings, Length: 4176, dtype: int64

# %%
X = df.drop('Rings',axis=1)
X
# Out:
#       Sex  Length   Diam  Height   Whole  Shucked  Viscera   Shell
# 0       2   0.350  0.265   0.090  0.2255   0.0995   0.0485  0.0700
# 1       0   0.530  0.420   0.135  0.6770   0.2565   0.1415  0.2100
# 2       2   0.440  0.365   0.125  0.5160   0.2155   0.1140  0.1550
# 3       1   0.330  0.255   0.080  0.2050   0.0895   0.0395  0.0550
# 4       1   0.425  0.300   0.095  0.3515   0.1410   0.0775  0.1200
# ...   ...     ...    ...     ...     ...      ...      ...     ...
# 4171    0   0.565  0.450   0.165  0.8870   0.3700   0.2390  0.2490
# 4172    2   0.590  0.440   0.135  0.9660   0.4390   0.2145  0.2605
# 4173    2   0.600  0.475   0.205  1.1760   0.5255   0.2875  0.3080
# 4174    0   0.625  0.485   0.150  1.0945   0.5310   0.2610  0.2960
# 4175    2   0.710  0.555   0.195  1.9485   0.9455   0.3765  0.4950
#
# [4176 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)

# %%
X_train
# Out:
#       Sex  Length   Diam  Height   Whole  Shucked  Viscera   Shell
# 2428    2   0.340  0.255   0.095  0.2130   0.0810   0.0340  0.0700
# 3823    2   0.620  0.460   0.170  1.1270   0.5350   0.2635  0.2960
# 3956    0   0.555  0.440   0.155  1.0160   0.4935   0.1855  0.2630
# 3623    0   0.665  0.500   0.175  1.4355   0.6430   0.3450  0.3700
# 0       2   0.350  0.265   0.090  0.2255   0.0995   0.0485  0.0700
# ...   ...     ...    ...     ...     ...      ...      ...     ...
# 3444    1   0.495  0.400   0.145  0.5780   0.2545   0.1305  0.1645
# 466     2   0.655  0.530   0.195  1.3880   0.5670   0.2735  0.4100
# 3092    0   0.520  0.430   0.150  0.7280   0.3020   0.1575  0.2350
# 3772    0   0.575  0.460   0.150  0.9270   0.3330   0.2070  0.2985
# 860     0   0.595  0.465   0.140  1.1130   0.5175   0.2440  0.3050
#
# [3132 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression



model = LinearRegression()

model.fit(X_train, y_train)



from sklearn.metrics import mean_squared_error



ly_preds = model.predict(X_test)

mse = np.sqrt(mean_squared_error(ly_preds, y_test))

print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 2.2700433076905293

# %%
iris = pd.read_csv('D:GC/iris.data')
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
iris.columns = ['sepal_length','sepal_width','petal_length','petal_width','class']
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
y=iris['class']
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 144    Iris-virginica
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# Name: class, Length: 149, dtype: object

# %%
x=iris.drop('class',axis=1)
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             4.9          3.0           1.4          0.2
# 1             4.7          3.2           1.3          0.2
# 2             4.6          3.1           1.5          0.2
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# ..            ...          ...           ...          ...
# 144           6.7          3.0           5.2          2.3
# 145           6.3          2.5           5.0          1.9
# 146           6.5          3.0           5.2          2.0
# 147           6.2          3.4           5.4          2.3
# 148           5.9          3.0           5.1          1.8
#
# [149 rows x 4 columns]

# %%
y=iris['petal_width']
y
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.4
#       ...
# 144    2.3
# 145    1.9
# 146    2.0
# 147    2.3
# 148    1.8
# Name: petal_width, Length: 149, dtype: float64

# %%
X=x.drop('petal_width',axis=1)
X
# Out:
#      sepal_length  sepal_width  petal_length
# 0             4.9          3.0           1.4
# 1             4.7          3.2           1.3
# 2             4.6          3.1           1.5
# 3             5.0          3.6           1.4
# 4             5.4          3.9           1.7
# ..            ...          ...           ...
# 144           6.7          3.0           5.2
# 145           6.3          2.5           5.0
# 146           6.5          3.0           5.2
# 147           6.2          3.4           5.4
# 148           5.9          3.0           5.1
#
# [149 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)

# %%
X_train
# Out:
#      sepal_length  sepal_width  petal_length
# 4             5.4          3.9           1.7
# 32            5.5          4.2           1.4
# 120           5.6          2.8           4.9
# 85            6.7          3.1           4.7
# 86            6.3          2.3           4.4
# ..            ...          ...           ...
# 71            6.3          2.5           4.9
# 106           7.3          2.9           6.3
# 14            5.7          4.4           1.5
# 92            5.0          2.3           3.3
# 102           6.3          2.9           5.6
#
# [111 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression



model = LinearRegression()

model.fit(X_train, y_train)



from sklearn.metrics import mean_squared_error



ly_preds = model.predict(X_test)

mse = np.sqrt(mean_squared_error(ly_preds, y_test))

print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 0.1935144066940702

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
label=LabelEncoder()
iris['class']=label.fit_transform(iris['class'])
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class
# 0             4.9          3.0           1.4          0.2      0
# 1             4.7          3.2           1.3          0.2      0
# 2             4.6          3.1           1.5          0.2      0
# 3             5.0          3.6           1.4          0.2      0
# 4             5.4          3.9           1.7          0.4      0
# ..            ...          ...           ...          ...    ...
# 144           6.7          3.0           5.2          2.3      2
# 145           6.3          2.5           5.0          1.9      2
# 146           6.5          3.0           5.2          2.0      2
# 147           6.2          3.4           5.4          2.3      2
# 148           5.9          3.0           5.1          1.8      2
#
# [149 rows x 5 columns]

# %%
y=iris['class']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 144    2
# 145    2
# 146    2
# 147    2
# 148    2
# Name: class, Length: 149, dtype: int32

# %%
x=iris.drop('class',axis=1)
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             4.9          3.0           1.4          0.2
# 1             4.7          3.2           1.3          0.2
# 2             4.6          3.1           1.5          0.2
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# ..            ...          ...           ...          ...
# 144           6.7          3.0           5.2          2.3
# 145           6.3          2.5           5.0          1.9
# 146           6.5          3.0           5.2          2.0
# 147           6.2          3.4           5.4          2.3
# 148           5.9          3.0           5.1          1.8
#
# [149 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC

clf_svm = SVC(random_state=0)
clf_svm.fit(x_train, y_train)

pred_svm = clf_svm.predict(x_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 6
#       3 from sklearn.svm import SVC
#       5 clf_svm = SVC(random_state=0)
# ----> 6 clf_svm.fit(x_train, y_train)
#       8 pred_svm = clf_svm.predict(x_test)
#      10 print("\n--- SVM Classifier ---")
#
# NameError: name 'x_train' is not defined

# %%
pred_svm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 pred_svm
#
# NameError: name 'pred_svm' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor

rf_clf = RandomForestRegressor()
rf_clf.fit(X_train, y_train)

pred_rf = rf_clf.predict(X_test)

print(rf_clf.score(X_train, y_train))
# Out:
# 0.9963830366098295

# %%
from sklearn.linear_model import LogisticRegression

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(x_train, y_train)

pred_lr = clf_lr.predict(x_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred_lr))
print (confusion_matrix(y_test, pred_lr))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       1 from sklearn.linear_model import LogisticRegression
#       3 clf_lr = LogisticRegression(random_state=0)
# ----> 4 clf_lr.fit(x_train, y_train)
#       6 pred_lr = clf_lr.predict(x_test)
#       8 print ("\n--- Logistic Regression Classifier ---")
#
# NameError: name 'x_train' is not defined

# %%
df.isnull().sum()
# Out:
# Sex        0
# Length     0
# Diam       0
# Height     0
# Whole      0
# Shucked    0
# Viscera    0
# Shell      0
# Rings      0
# dtype: int64

# %%
df.describe()
# Out:
#                Sex       Length         Diam       Height        Whole  \
# count  4176.000000  4176.000000  4176.000000  4176.000000  4176.000000
# mean      1.052682     0.524009     0.407892     0.139527     0.828818
# std       0.822208     0.120103     0.099250     0.041826     0.490424
# min       0.000000     0.075000     0.055000     0.000000     0.002000
# 25%       0.000000     0.450000     0.350000     0.115000     0.441500
# 50%       1.000000     0.545000     0.425000     0.140000     0.799750
# 75%       2.000000     0.615000     0.480000     0.165000     1.153250
# max       2.000000     0.815000     0.650000     1.130000     2.825500
#
#           Shucked      Viscera        Shell        Rings
# count  4176.00000  4176.000000  4176.000000  4176.000000
# mean      0.35940     0.180613     0.238852     9.932471
# std       0.22198     0.109620     0.139213     3.223601
# min       0.00100     0.000500     0.001500     1.000000
# ...

# %%
df.mode()
# Out:
#    Sex  Length  Diam  Height   Whole  Shucked  Viscera  Shell  Rings
# 0  2.0   0.550  0.45    0.15  0.2225    0.175   0.1715  0.275    9.0
# 1  NaN   0.625   NaN     NaN     NaN      NaN      NaN    NaN    NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame(np.random.randn(10,2),columns=['Length','Diameter'])
df.loc[1,'Length']=11
df.loc[3,'Diameter']=10
plt.boxplot([df['Length'],df['Diameter']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13277a98cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x13277a9a490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x13277a8fd50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x13277a9bc50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x13277aa4750>,
# ...
#  'means': []}

# %%
df=df[df.Length>0.75,df.Length<8]
df.Length.min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\anaconda\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\anaconda\Lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: Length, dtype: bool, 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Length, dtype: bool)' is an invalid key
#
# ...

# %%
df=df[df.Diameter>0]
df.Diameter.min()

# %%
df = pd.DataFrame(np.random.randn(10,2),columns=['Length','Diameter'])
df.loc[1,'Length']=11
df.loc[3,'Diameter']=10
plt.boxplot([df['Length'],df['Diameter']])

# %%
df
# Out:
#       Length   Diameter
# 0  -0.148708  -1.875488
# 1  11.000000  -0.359340
# 2  -0.001367  -1.000744
# 3   0.988645  10.000000
# 4   0.247494  -0.033206
# 5  -0.735516   0.184559
# 6   0.401791   0.980698
# 7   1.037841   1.306884
# 8   0.672616  -1.752302
# 9  -1.777558   0.035156

# %%
df.groupby('Rings').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.groupby('Rings').count()
#
# File C:\anaconda\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
df.groupby('Rings')['Whole'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.groupby('Rings')['Whole'].mean()
#
# File C:\anaconda\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
df.groupby('Rings')['Shucked','Whole','Shell'].mean()

# %%
df.hist(figsize=(20,10), grid=False, layout=(2,4),bins=30)
# Out:
# array([[<Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diameter'}>, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
y=df['Rings']
x=df.drop('Rings',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\anaconda\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\anaconda\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rings'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=423)
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix

from sklearn.tree import DecisionTreeRegressor


clf_lr = LinearRegression()

clf_lr.fit(X_train, y_train)



pred_lr = clf_lr.predict(X_test)

mse = np.sqrt(mean_squared_error(pred_lr, y_test))

print('평균제곱근오차', mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 17
#      11 clf_lr.fit(X_train, y_train)
#      15 pred_lr = clf_lr.predict(X_test)
# ---> 17 mse = np.sqrt(mean_squared_error(pred_lf, y_test))
#      19 print('평균제곱근오차', mse)
#
# NameError: name 'pred_lf' is not defined
