# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
index= np.arange(7)

data= pd.read_excel('D:GC/04_data1.xlsx',index_col='area')

plt.figure(figsize=(10,4))

data6 = data.loc['Seoul':'Ulsan','2017_common':'2020_common']
for year in range(2017,2021):
    year = str(year)+'_common'
    chartdata=data6[year]
    plt.barh(index, chartdata, label=year)
    
    plt.xlim(120,310)
    plt.ylabel('Area')
    plt.xlabel('Micrometer')
    plt.yticks(index,['Seoul','Busan','Daegu','Incheon','Guangju','Daejeon','Ulsan'])
    plt.title('2017~2020 Fine Dust(pm10) Common Group Barh Graph')
    plt.legend()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data= pd.read_csv('D:GC/titanic.csv')

data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
Fare = data['Fare']
Pclass = data['Pclass']

plt.figure(figsize=(10,4))
plt.scatter(Pclass,Fare,color='r')

plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.title('Fare & Pclass')
plt.grid()
plt.show()

# %%
newdata=data.copy().head(100)
newdata
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# 95                        Shorney, Mr. Charles Joseph    male   NaN      0
# 96                          Goldschmidt, Mr. George B    male  71.0      0
# 97                    Greenfield, Mr. William Bertram    male  23.0      0
# 98               Doling, Mrs. John T (Ada Julia Bone)  female  34.0      0
# 99                                  Kantor, Mr. Sinai    male  34.0      1
#
#     Parch            Ticket     Fare    Cabin Embarked
# 0       0         A/5 21171   7.2500      NaN        S
# 1       0          PC 17599  71.2833      C85        C
# 2       0  STON/O2. 3101282   7.9250      NaN        S
# 3       0            113803  53.1000     C123        S
# 4       0            373450   8.0500      NaN        S
# ..    ...               ...      ...      ...      ...
# 95      0            374910   8.0500      NaN        S
# 96      0          PC 17754  34.6542       A5        C
# 97      1          PC 17759  63.3583  D10 D12        C
# 98      1            231919  23.0000      NaN        S
# 99      0            244367  26.0000      NaN        S
#
# [100 rows x 12 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 Fare= data.loc[data.Passengerld=='PassengerId','Fare']
#       3 plt.figure(figsize=(10,6))
#       4 plt.hist(Fare['Fare'], bins=8, label='Fare')
#
# File C:\anaconda\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Passengerld'

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Fare'], bins=8, color='skyblue')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.title('Fare')
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
avg=data['Age'].mean()
data['Age']=data['Age'].fillna(avg)
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
newdata=data.copy().head(100)
newdata
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex        Age  \
# 0                             Braund, Mr. Owen Harris    male  22.000000
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                              Heikkinen, Miss. Laina  female  26.000000
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                            Allen, Mr. William Henry    male  35.000000
# ..                                                ...     ...        ...
# 95                        Shorney, Mr. Charles Joseph    male  29.699118
# 96                          Goldschmidt, Mr. George B    male  71.000000
# 97                    Greenfield, Mr. William Bertram    male  23.000000
# 98               Doling, Mrs. John T (Ada Julia Bone)  female  34.000000
# 99                                  Kantor, Mr. Sinai    male  34.000000
#
#     SibSp  Parch            Ticket     Fare    Cabin Embarked
# 0       1      0         A/5 21171   7.2500      NaN        S
# 1       1      0          PC 17599  71.2833      C85        C
# 2       0      0  STON/O2. 3101282   7.9250      NaN        S
# 3       1      0            113803  53.1000     C123        S
# 4       0      0            373450   8.0500      NaN        S
# ..    ...    ...               ...      ...      ...      ...
# 95      0      0            374910   8.0500      NaN        S
# 96      0      0          PC 17754  34.6542       A5        C
# 97      0      1          PC 17759  63.3583  D10 D12        C
# 98      0      1            231919  23.0000      NaN        S
# 99      1      0            244367  26.0000      NaN        S
#
# [100 rows x 12 columns]

# %%
plt.figure(figsize=(10,6))

plt.hist(newdata['Fare'],bins=5,alpha=0.5,label='Fare')
plt.hist(newdata['Age'],bins=5,alpha=0.5,label='Age')

plt.xlabel('amount')
plt.ylabel('frequency')
plt.title('Age&Fare')
plt.legend()
plt.grid()
plt.show()

# %%
Age=newdata['Age']

plt.figure(figsize=(8,5))
plt.boxplot([Age,Fare], labels=['Age','Fare'],vert=False)

plt.xlabel('Age')
plt.ylabel('Value')
plt.title('Box')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data= pd.read_excel('D:/GC/04_data1.xlsx',index_col='area')
data
# Out:
#               2015_good  2016_good  2017_good  2018_good  2019_good  \
# area
# Nationwide         72.0         54         84        135        117
# Metropolitan       72.0         45         77        126        109
# Seoul              97.0         65        113        140        139
# Busan             102.0         89         86        136        163
# Daegu              90.0        103        111        155        148
# Incheon            67.0         49         78        140        115
# Gwangju           122.0        151        134        149        117
# Daejeon           111.0         92         83        121        143
# Ulsan             101.0        101        104        162        173
# Sejong              NaN         65         69        130        127
# Gyeonggi           65.0         45         59        123         97
# Gangwon            77.0         65        108        150        159
# Chungbuk           90.0         99        106        117        113
# Chungnam           94.0         65         74        144         96
# Jeonbuk            86.0         58         69        121        108
# Jeonnam           142.0        166        160        191        193
# Gyeongbuk         101.0        123        124        129        142
# Gyeongnam          76.0         75         93        136        136
# Jeju               84.0        138        166        202        176
#
#               2020_good  2015_common  2016_common  2017_common  2018_common  \
# area
# Nationwide          171        267.0          297          265          209
# Metropolitan        150        259.0          290          260          217
# Seoul               168        243.0          277          230          204
# Busan               208        242.0          259          269          212
# Daegu               176        248.0          246          244          196
# Incheon             182        256.0          299          264          207
# Gwangju             210        220.0          200          216          193
# Daejeon             182        225.0          255          268          219
# Ulsan               206        242.0          252          250          184
# Sejong              165          NaN          285          279          215
# Gyeonggi            137        261.0          285          269          216
# Gangwon             219        260.0          285          241          199
# Chungbuk            164        236.0          243          242          220
# Chungnam            145        244.0          286          271          202
# Jeonbuk             171        239.0          274          269          212
# Jeonnam             247        214.0          191          201          164
# Gyeongbuk           212        246.0          235          232          214
# Gyeongnam           220        271.0          274          264          215
# Jeju                220        259.0          211          192          147
#
#               ...  2017_bad  2018_bad  2019_bad  2020_bad  2015_verybad  \
# area          ...
# Nationwide    ...        14        21        16         0           1.0
# Metropolitan  ...        26        22        27         4           4.0
# Seoul         ...        20        21        25         5           4.0
# Busan         ...        10        16         9         2           1.0
# Daegu         ...        10        13        17         4           1.0
# Incheon       ...        21        18        21         2           2.0
# Gwangju       ...        12        21        19         0           2.0
# Daejeon       ...        12        24        21         1           1.0
# Ulsan         ...        10        18        11         2           1.0
# Sejong        ...        15        19        24         4           NaN
# Gyeonggi      ...        35        26        32         6           4.0
# Gangwon       ...        15        16        11         3           3.0
# Chungbuk      ...        15        27        23         3           1.0
# Chungnam      ...        18        19        17         6           2.0
# Jeonbuk       ...        24        32        22         1           3.0
# Jeonnam       ...         1        10         6         0           1.0
# Gyeongbuk     ...         9        21        17         2           1.0
# Gyeongnam     ...         8        13        10         0           1.0
# Jeju          ...         5        14         9         2           2.0
#
#               2016_verybad  2017_verybad  2018_verybad  2019_verybad  \
# area
# Nationwide               2             2             0             1
# Metropolitan             2             2             0             3
# Seoul                    1             2             0             3
# Busan                    2             0             1             0
# Daegu                    1             0             1             0
# Incheon                  2             2             0             2
# Gwangju                  4             3             2             2
# Daejeon                  2             2             1             3
# Ulsan                    2             1             1             0
# Sejong                   1             2             1             5
# Gyeonggi                 2             2             0             3
# Gangwon                  2             1             0             1
# Chungbuk                 1             2             1             1
# Chungnam                 2             2             0             3
# Jeonbuk                  3             3             0             3
# Jeonnam                  0             3             0             0
# Gyeongbuk                1             0             1             0
# Gyeongnam                2             0             1             0
# Jeju                     0             2             0             1
#
#               2020_verybad
# area
# Nationwide               0
# Metropolitan             0
# Seoul                    0
# Busan                    0
# Daegu                    0
# Incheon                  0
# Gwangju                  0
# Daejeon                  0
# Ulsan                    0
# Sejong                   0
# Gyeonggi                 0
# Gangwon                  0
# Chungbuk                 0
# Chungnam                 0
# Jeonbuk                  0
# Jeonnam                  0
# Gyeongbuk                0
# Gyeongnam                0
# Jeju                     0
#
# [19 rows x 24 columns]

# %%
data.isnull().sum()
# Out:
# 2015_good       0
# 2016_good       0
# 2017_good       0
# 2018_good       0
# 2019_good       0
# 2020_good       0
# 2015_common     0
# 2016_common     0
# 2017_common     0
# 2018_common     0
# 2019_common     0
# 2020_common     0
# 2015_bad        0
# 2016_bad        0
# 2017_bad        0
# 2018_bad        0
# 2019_bad        0
# 2020_bad        0
# 2015_verybad    1
# 2016_verybad    0
# 2017_verybad    0
# 2018_verybad    0
# 2019_verybad    0
# 2020_verybad    0
# dtype: int64

# %%
avg=data['2015_good'].mean()
data['2015_good']=data['2015_good'].fillna(avg)
data.isnull().sum()
avg=data['2015_common'].mean()
data['2015_common']=data['2015_common'].fillna(avg)
data.isnull().sum()
avg=data['2015_bad'].mean()
data['2015_bad']=data['2015_bad'].fillna(avg)
data.isnull().sum()
data
# Out:
#                2015_good  2016_good  2017_good  2018_good  2019_good  \
# area
# Nationwide     72.000000         54         84        135        117
# Metropolitan   72.000000         45         77        126        109
# Seoul          97.000000         65        113        140        139
# Busan         102.000000         89         86        136        163
# Daegu          90.000000        103        111        155        148
# Incheon        67.000000         49         78        140        115
# Gwangju       122.000000        151        134        149        117
# Daejeon       111.000000         92         83        121        143
# Ulsan         101.000000        101        104        162        173
# Sejong         91.611111         65         69        130        127
# Gyeonggi       65.000000         45         59        123         97
# Gangwon        77.000000         65        108        150        159
# Chungbuk       90.000000         99        106        117        113
# Chungnam       94.000000         65         74        144         96
# Jeonbuk        86.000000         58         69        121        108
# Jeonnam       142.000000        166        160        191        193
# Gyeongbuk     101.000000        123        124        129        142
# Gyeongnam      76.000000         75         93        136        136
# Jeju           84.000000        138        166        202        176
#
#               2020_good  2015_common  2016_common  2017_common  2018_common  \
# area
# Nationwide          171   267.000000          297          265          209
# Metropolitan        150   259.000000          290          260          217
# Seoul               168   243.000000          277          230          204
# Busan               208   242.000000          259          269          212
# Daegu               176   248.000000          246          244          196
# Incheon             182   256.000000          299          264          207
# Gwangju             210   220.000000          200          216          193
# Daejeon             182   225.000000          255          268          219
# Ulsan               206   242.000000          252          250          184
# Sejong              165   246.222222          285          279          215
# Gyeonggi            137   261.000000          285          269          216
# Gangwon             219   260.000000          285          241          199
# Chungbuk            164   236.000000          243          242          220
# Chungnam            145   244.000000          286          271          202
# Jeonbuk             171   239.000000          274          269          212
# Jeonnam             247   214.000000          191          201          164
# Gyeongbuk           212   246.000000          235          232          214
# Gyeongnam           220   271.000000          274          264          215
# Jeju                220   259.000000          211          192          147
#
#               ...  2017_bad  2018_bad  2019_bad  2020_bad  2015_verybad  \
# area          ...
# Nationwide    ...        14        21        16         0           1.0
# Metropolitan  ...        26        22        27         4           4.0
# Seoul         ...        20        21        25         5           4.0
# Busan         ...        10        16         9         2           1.0
# Daegu         ...        10        13        17         4           1.0
# Incheon       ...        21        18        21         2           2.0
# Gwangju       ...        12        21        19         0           2.0
# Daejeon       ...        12        24        21         1           1.0
# Ulsan         ...        10        18        11         2           1.0
# Sejong        ...        15        19        24         4           NaN
# Gyeonggi      ...        35        26        32         6           4.0
# Gangwon       ...        15        16        11         3           3.0
# Chungbuk      ...        15        27        23         3           1.0
# Chungnam      ...        18        19        17         6           2.0
# Jeonbuk       ...        24        32        22         1           3.0
# Jeonnam       ...         1        10         6         0           1.0
# Gyeongbuk     ...         9        21        17         2           1.0
# Gyeongnam     ...         8        13        10         0           1.0
# Jeju          ...         5        14         9         2           2.0
#
#               2016_verybad  2017_verybad  2018_verybad  2019_verybad  \
# area
# Nationwide               2             2             0             1
# Metropolitan             2             2             0             3
# Seoul                    1             2             0             3
# Busan                    2             0             1             0
# Daegu                    1             0             1             0
# Incheon                  2             2             0             2
# Gwangju                  4             3             2             2
# Daejeon                  2             2             1             3
# Ulsan                    2             1             1             0
# Sejong                   1             2             1             5
# Gyeonggi                 2             2             0             3
# Gangwon                  2             1             0             1
# Chungbuk                 1             2             1             1
# Chungnam                 2             2             0             3
# Jeonbuk                  3             3             0             3
# Jeonnam                  0             3             0             0
# Gyeongbuk                1             0             1             0
# Gyeongnam                2             0             1             0
# Jeju                     0             2             0             1
#
#               2020_verybad
# area
# Nationwide               0
# Metropolitan             0
# Seoul                    0
# Busan                    0
# Daegu                    0
# Incheon                  0
# Gwangju                  0
# Daejeon                  0
# Ulsan                    0
# Sejong                   0
# Gyeonggi                 0
# Gangwon                  0
# Chungbuk                 0
# Chungnam                 0
# Jeonbuk                  0
# Jeonnam                  0
# Gyeongbuk                0
# Gyeongnam                0
# Jeju                     0
#
# [19 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['2015_good', '2016_good', '2017_good', '2018_good', '2019_good',
#        '2020_good', '2015_common', '2016_common', '2017_common', '2018_common',
#        '2019_common', '2020_common', '2015_bad', '2016_bad', '2017_bad',
#        '2018_bad', '2019_bad', '2020_bad', '2015_verybad', '2016_verybad',
#        '2017_verybad', '2018_verybad', '2019_verybad', '2020_verybad'],
#       dtype='object')

# %%
plt.figure(figsize=(8,5))
plt.boxplot([data['2015_good'],data['2015_common'],data['2015_bad']])

plt.xlabel('width')
plt.ylabel('value')
plt.title('dust')
plt.show()

# %%
import seaborn as sns

data= pd.read_excel('D:GC/05_data1.xlsx')
data
# Out:
#         no  city_code  gender  age_code  height  weight  waist  systolic  \
# 0        1         36       1         9     165      60   72.1       127
# 1        5         41       2        12     155      50   75.2       144
# 2        6         27       1         9     185      85   94.0       114
# 3        7         44       1         9     165      80   93.0       112
# 4        9         41       2        17     150      50   82.0       136
# ...    ...        ...     ...       ...     ...     ...    ...       ...
# 2995  7648         31       2        11     155      55   68.0       132
# 2996  7650         42       1        13     155      60   79.0       123
# 2997  7651         41       1         9     165      60   85.0       118
# 2998  7652         42       1         9     180      90   97.0       148
# 2999  7659         44       1        11     160      65   89.8       125
#
#       diastolic  blood_sugar  cholesterol  triglycerides   HDL  LDL  \
# 0            79           90          188             58  58.0  118
# 1            89          110          220            171  53.0  133
# 2            72           86          234            183  50.0  147
# 3            73          250          119            265  26.0   40
# 4            65          104          177             61  63.0  101
# ...         ...          ...          ...            ...   ...  ...
# 2995         82           97          198             60  80.0  106
# 2996         68           90          157            122  46.0   86
# 2997         81           81          100             55  46.0   43
# 2998         90          101          235            232  43.0  145
# 2999         75           95          222            141  39.0  155
#
#       hemoglobin  serum  smoking  drinking
# 0           15.0    1.1        1         0
# 1           12.4    0.7        1         0
# 2           16.4    1.1        3         1
# 3           15.7    0.7        3         1
# 4           13.3    0.7        1         0
# ...          ...    ...      ...       ...
# 2995        10.6    0.9        1         1
# 2996        15.0    0.8        1         0
# 2997        15.1    0.8        1         0
# 2998        16.6    0.7        1         1
# 2999        14.9    1.1        2         1
#
# [3000 rows x 18 columns]

# %%
data.isnull().sum()
# Out:
# no               0
# city_code        0
# gender           0
# age_code         0
# height           0
# weight           0
# waist            0
# systolic         0
# diastolic        0
# blood_sugar      0
# cholesterol      0
# triglycerides    0
# HDL              0
# LDL              0
# hemoglobin       0
# serum            0
# smoking          0
# drinking         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['no', 'city_code', 'gender', 'age_code', 'height', 'weight', 'waist',
#        'systolic', 'diastolic', 'blood_sugar', 'cholesterol', 'triglycerides',
#        'HDL', 'LDL', 'hemoglobin', 'serum', 'smoking', 'drinking'],
#       dtype='object')

# %%
data6 = data.loc[:,['gender','height','weight','waist','drinking','smoking']]

data6.loc[data6['gender']==1,['gender']]='M'
data6.loc[data6['gender']==2,['gender']]='F'
data6.loc[data6['drinking']==0,['drinking']]='Non-drinking'
data6.loc[data6['drinking']==1,['drinking']]='Drinking'
data6.loc[data6['smoking']==1,['smoking']]='Non-smoking'
data6.loc[data6['smoking']==2,['smoking']]='Quit-smoking'
data6.loc[data6['smoking']==3,['smoking']]='Smoking'
data6
# Out:
#      gender  height  weight  waist      drinking       smoking
# 0         M     165      60   72.1  Non-drinking   Non-smoking
# 1         F     155      50   75.2  Non-drinking   Non-smoking
# 2         M     185      85   94.0      Drinking       Smoking
# 3         M     165      80   93.0      Drinking       Smoking
# 4         F     150      50   82.0  Non-drinking   Non-smoking
# ...     ...     ...     ...    ...           ...           ...
# 2995      F     155      55   68.0      Drinking   Non-smoking
# 2996      M     155      60   79.0  Non-drinking   Non-smoking
# 2997      M     165      60   85.0  Non-drinking   Non-smoking
# 2998      M     180      90   97.0      Drinking   Non-smoking
# 2999      M     160      65   89.8      Drinking  Quit-smoking
#
# [3000 rows x 6 columns]

# %%
drinking = data6.groupby(['gender','drinking'])['drinking'].count()
smoking = data6.groupby(['gender','smoking'])['smoking'].count()
drinking = drinking.to_frame(name='count')
smoking = smoking.to_frame(name='count')
drinking = drinking.reset_index()
smoking = smoking.reset_index()

drinking
# Out:
#   gender      drinking  count
# 0      F      Drinking    611
# 1      F  Non-drinking    888
# 2      M      Drinking   1086
# 3      M  Non-drinking    415

# %%
smoking
# Out:
#   gender       smoking  count
# 0      F   Non-smoking   1422
# 1      F  Quit-smoking     45
# 2      F       Smoking     32
# 3      M   Non-smoking    502
# 4      M  Quit-smoking    519
# 5      M       Smoking    480

# %%
fig = plt.figure(figsize=(12,10))
fig.subtitle('2020 Health Check Drinking & Smoking Type Bar Graph',fontweight = 'bold')
index1 = np.arange(4)
index2 = np.arange(6)

fig.add_subplot(2,1,1)

plt.bar(index1,drinking['count'])
plt.title('Drinking Type')
plt.ylabel('Count')
plt.xticks(index1, ['Non-drinking(M)','Drinking(M)','Non-drinking(F)','Drinking(F)'])

fig.add_subplot(2,1,2)
plt.bar(index2, smoking['count'])
plt.title('Smoking Type')
plt.ylabel('Count')
plt.xticks(index2, ['Non-smoking(M)','Quit-smoking(M)','Smoking(M),''Non-smoking(F)','Quit-smoking(F)','Smoking(F),'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 2
#       1 fig = plt.figure(figsize=(12,10))
# ----> 2 fig.subtitle('2020 Health Check Drinking & Smoking Type Bar Graph',fontweight = 'bold')
#       3 index1 = np.arange(4)
#       4 index2 = np.arange(6)
#
# AttributeError: 'Figure' object has no attribute 'subtitle'

# %%
newdata = data.loc[:,['gender','age_code','height','weight','blood_sugar']]
newdata
# Out:
#       gender  age_code  height  weight  blood_sugar
# 0          1         9     165      60           90
# 1          2        12     155      50          110
# 2          1         9     185      85           86
# 3          1         9     165      80          250
# 4          2        17     150      50          104
# ...      ...       ...     ...     ...          ...
# 2995       2        11     155      55           97
# 2996       1        13     155      60           90
# 2997       1         9     165      60           81
# 2998       1         9     180      90          101
# 2999       1        11     160      65           95
#
# [3000 rows x 5 columns]

# %%
newdata.loc[data6['gender']==1,['gender']]='M'
newdata.loc[data6['gender']==2,['gender']]='F'
newdata.loc[data6['blood_sugar']>=120,['blood_sugar']]='Over'
newdata.loc[data6['blood_sugar']<120,['blood_sugar']]='Under'
newdata
# Out:
#      gender  age_code height  weight  blood_sugar
# 0         1         9   Over      60           90
# 1         2        12   Over      50          110
# 2         1         9   Over      85           86
# 3         1         9   Over      80          250
# 4         2        17   Over      50          104
# ...     ...       ...    ...     ...          ...
# 2995      2        11   Over      55           97
# 2996      1        13   Over      60           90
# 2997      1         9   Over      60           81
# 2998      1         9   Over      90          101
# 2999      1        11   Over      65           95
#
# [3000 rows x 5 columns]

# %%
blood_sugar=newdata.groupby(['gender','blood_sugar'])['blood_sugar'].count()
blood_sugar=blood_sugar.to_frame(name='count')
blood_sugar=blood_sugar.reset_index()

blood_sugar
# Out:
#      gender  blood_sugar  count
# 0         1           62      2
# 1         1           63      1
# 2         1           65      1
# 3         1           69      1
# 4         1           70      2
# ..      ...          ...    ...
# 243       2          230      1
# 244       2          245      1
# 245       2          254      1
# 246       2          273      1
# 247       2          319      1
#
# [248 rows x 3 columns]
