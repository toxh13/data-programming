# %%
import pandas as pd

# %%
df = pd.read_csv('D:GC/music.csv')

# %%
df
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# ...

# %%
newdata=df.groupby('genre').count()
pd.DataFrame(newdata['personnel'])
# Out:
#        personnel
# genre
# R&B            1
# 댄스            10
# 발라드            1
# 힙합             1

# %%
newdata=df.groupby(['sortation','genre']).sum()
pd.DataFrame(newdata['personnel'])
# Out:
# C:\TempFolder\ipykernel_5216\11994014.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   newdata=df.groupby(['sortation','genre']).sum()
#                  personnel
# sortation genre
# 그룹        R&B            7
#           댄스            59
# 솔로        발라드            1
#           힙합             1

# %%
df = pd.read_csv('D:GC/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df['Embarked'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# Out:
# C:\TempFolder\ipykernel_5216\3258272102.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.head(10)[df['Age'].isna()]
#    PassengerId  Survived  Pclass              Name   Sex  Age  SibSp  Parch  \
# 5            6         0       3  Moran, Mr. James  male  NaN      0      0
#
#    Ticket    Fare Cabin Embarked
# 5  330877  8.4583   NaN        Q

# %%
df.drop('Cabin',axis=1,inplace=True)
df.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.drop('Cabin',axis=1,inplace=True)
#       2 df.columns
#
# File C:\anaconda\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\anaconda\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
import matplotlib.pyplot as plt
plt.title('Line Graph')
xdata = [3,5,7,9]
ydata=[2,4,6,8]
plt.plot(xdata,ydata)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
plt.title('Legend properties')
data1 = [1,3,5,7]
data2=[9,7,5,3]
plt.plot(data1,label='salary')
plt.plot(data2,label='Prices')
plt.legend()
plt.show()

# %%
data = pd.read_excel('D:GC/04_data1.xlsx',index_col='area')
data.head()
# Out:
#               2015_good  2016_good  2017_good  2018_good  2019_good  \
# area
# Nationwide         72.0         54         84        135        117
# Metropolitan       72.0         45         77        126        109
# Seoul              97.0         65        113        140        139
# Busan             102.0         89         86        136        163
# Daegu              90.0        103        111        155        148
#
#               2020_good  2015_common  2016_common  2017_common  2018_common  \
# area
# Nationwide          171        267.0          297          265          209
# Metropolitan        150        259.0          290          260          217
# Seoul               168        243.0          277          230          204
# Busan               208        242.0          259          269          212
# Daegu               176        248.0          246          244          196
#
#               ...  2017_bad  2018_bad  2019_bad  2020_bad  2015_verybad  \
# ...

# %%
data2020_good = data['2020_good']

# %%
plt.figure(figsize=(20,4))
plt.plot(data2020_good, color='b',label='2020',marker='o')
plt.plot(data2019_good, color='r',label='2019',marker='s')
plt.xlabel('Area')
plt.ylabel('Micrometer')
plt.title('2020 Fine Dust(pm10) Good Line Graph')
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


bar_width=0.25
data2015_verybad=data['2015_verybad']
data2016_verybad=data['2016_verybad']
index = np.arange(2)

plt.figure(figsize=(20,4))
plt.bar(index,data2015_verybad.index, data2015_verybad, color='b',width=0.15, label='2015')
plt.bar(index,data2016_verybad.index, data2016_verybad, color='r',width=0.3, label='2016')

plt.xlabel('Area')
plt.ylabel('Micrometer')
plt.title('2015년과 2016년중 미세먼지가 별로인날')
plt.grid()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 11
#       8 index = np.arange(2)
#      10 plt.figure(figsize=(20,4))
# ---> 11 plt.bar(index,data2015_verybad.index, data2015_verybad, color='b',width=0.15, label='2015')
#      12 plt.bar(index,data2016_verybad.index, data2016_verybad, color='r',width=0.3, label='2016')
#      14 plt.xlabel('Area')
#
# TypeError: bar() got multiple values for argument 'width'

# %%
import numpy as np
index = np.arange(7)

plt.figure(figsize=(20,4))

data6= data.loc['Seoul' : 'Ulsan','2015_good':'2020_good']
for year in range(2015,2021):
    year = str(year)+'_good'
    chartdata=data6[year]
    plt.bar(index,chartdata,width=0.15,label=year)
    index= index+ 0.15
    
plt.xlabel('Area')
plt.ylabel('Micrometer')
plt.xticks(index-0.53,['Seoul','Busan','Daegu','Incheon','Gwangu','Daejeon','Ulsan'])
plt.title('2015~2020')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 10
#       8     year = str(year)+'_good'
#       9     chartdata=data6[year]
# ---> 10     plt.barh(index,chartdata,width=0.15,label=year)
#      11     index= index+ 0.15
#      13 plt.xlabel('Area')
#
# TypeError: barh() got multiple values for argument 'width'

# %%
import numpy as np
index = np.arange(7)

plt.figure(figsize=(20,4))

data6= data.loc['Seoul' : 'Ulsan','2015_good':'2020_good']
for year in range(2017,2021):
    year = str(year)+'_good'
    chartdata=data6[year]
    plt.barh(index,chartdata,label=year)
    
plt.xlim(120,310)    
plt.xlabel('Area')
plt.ylabel('Micrometer')
plt.yticks(index,['Seoul','Busan','Daegu','Incheon','Gwangu','Daejeon','Ulsan'])
plt.title('2015~2020')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('D:GC/04_data2.csv')
data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
PetalLength = data['PetalLength']
PetalWidth = data['PetalWidth']

plt.figure(figsize=(10,4))
plt.scatter(PetalLength, PetalWidth)

plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('Iris Petal Scatter Graph')
plt.grid()
plt.show()

# %%
PetalLength = data['PetalLength']
PetalWidth = data['PetalWidth']

SepalLength = data['SepalLength']
SepalWidth = data['SepalWidth']
plt.figure(figsize=(10,4))
plt.scatter(PetalLength, PetalWidth,color='r',edgecolor='w',label='PetalLength * PetalWidth')
plt.scatter(SepalLength, SepalWidth, color='b', edgecolor='w',label='SepalLength * SepalWidth')

plt.xlabel(' Length')
plt.ylabel(' Width')
plt.title('Iris Petal Scatter Graph')
plt.legend()
plt.grid()
plt.show()

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
setosa = data.loc[data.Species=='setosa',['Species','SepalWidth']]
versicolor = data.loc[data.Species=='versicolor',['Species','SepalWidth']]
plt.figure(figsize=(10,6))

plt.hist(setosa['SepalWidth'],bins=5,alpha=0.5,label='setosa',color='r')
plt.hist(versicolor['SepalWidth'],bins=5,alpha=0.5,label='versicolor',color='b')

plt.xlabel('Petal')
plt.ylabel('Length')
plt.title('Iris seto')
plt.legend()
plt.grid()
plt.show()

# %%
data = pd.read_csv('D:GC/titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
